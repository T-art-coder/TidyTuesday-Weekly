# %% [markdown]
# <a href="https://colab.research.google.com/github/T-art-coder/TidyTuesday-Weekly/blob/main/TidyTuesday%20W31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Download packages

# %%
#install.packages("caret")
#install.packages("gridExtra")
#install.packages("lubridate")
#install.packages("skimr")
#install.packages("tidyverse")
#install.packages("GGally")
#install.packages("scales")
library(caret)
library(gridExtra)
library(skimr)
library(tidyverse)
library(lubridate)
library(GGally)
library(scales)

# %%
#install.packages("showtext")
library(showtext)

# %%
install.packages("tidytuesdayR")
tuesdata <- tidytuesdayR::tt_load(2022, week = 31)

# %%
frog <- tuesdata$frogs

# %%
## Loading Google fonts (https://fonts.google.com/)
font_add_google("Gochi Hand", "gochi")
font_add_google("Schoolbell", "bell")

## Automatically use showtext to render text
showtext_auto()

# %% [markdown]
# ### Code

# %%
head(frog)
# Out:
#   Site          Subsite HabType SurveyDate Ordinal Frequency UTME_83 UTMN_83
# 1 Crane Prairie SE Pond Pond    2018-09-25 268     164.169   597369  4846486
# 2 Crane Prairie SE Pond Pond    2018-10-02 275     164.169   597352  4846487
# 3 Crane Prairie SE Pond Pond    2018-10-09 282     164.169   597345  4846458
# 4 Crane Prairie SE Pond Pond    2018-10-15 288     164.169   597340  4846464
# 5 Crane Prairie SE Pond Pond    2018-10-22 295     164.169   597344  4846460
# 6 Crane Prairie SE Pond Pond    2018-11-01 305     164.169   597410  4846451
#   Interval Female Water         Type       Structure      Substrate
# 1 0        0      Deep water    Marsh/Pond Herbaceous veg Unknown substrate
# 2 1        0      Deep water    Marsh/Pond Open           Unknown substrate
# 3 2        0      Shallow water Marsh/Pond Herbaceous veg Unknown substrate
# 4 3        0      Deep water    Marsh/Pond Woody debris   Unknown substrate
# 5 4        0      Deep water    Marsh/Pond Woody veg      Unknown substrate
# 6 5        0      Deep water    Marsh/Pond Herbaceous veg Unknown substrate
#   Beaver    Detection Female_ch
# 1 No beaver Captured  Male
# 2 No beaver No visual Male
# 3 No beaver No visual Male
# 4 No beaver No visual Male
# 5 No beaver No visual Male
# 6 No beaver No visual Male

# %% [markdown]
# ### Some data wrangling

# %%
frog$Female_ch <- as.factor(frog$Female)
frog$SurveyDate <- as.Date(mdy(frog$SurveyDate))

# %%
levels(frog$Female_ch) <- list(Male = "0", 
                                Female = "1")
frog$Female_ch

# %% [markdown]
# ### Exploring data

# %%
sample_cat_features <- c("Site", "Subsite", "HabType", "Water", "Type", "Structure", "Substrate", "Beaver", "Detection", "Female_ch")

# We find a date column
# Column 'SurveyDate' has more levels (41) than the threshold (15) allowed.
# Ordinal - basically it is date

# %%
ggpairs(frog, columns = c(sample_cat_features), aes(color = as.factor(Female)))+
  theme_classic()
# Out:
# plot without title

# %%
frog %>% select(HabType, SurveyDate, Female) %>% arrange(SurveyDate) %>% group_by(SurveyDate) %>% summarize(n = n()) %>%
  ggplot(aes(x = SurveyDate, y = n)) +
  geom_point()+
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Final Plot

# %%
frog_pic <- frog %>% select(HabType, SurveyDate, Female_ch) %>% arrange(SurveyDate) %>% group_by(SurveyDate, HabType, Female_ch) %>% summarize(n = n()) %>%
  ggplot(aes(x = SurveyDate, y = n, color = HabType)) +
  geom_point(alpha = 0.1) +
  geom_smooth(alpha = 0.1)+
  facet_wrap(~ Female_ch) +
  theme_minimal(base_family = "bell", base_size = 12)+
  theme(axis.title.y = element_text(size = rel(1.9)),
        axis.title.x = element_blank(),
        # grid subtitles
        strip.text.x = element_text(
          size = rel(2.1), color = "red", face = "bold"),
        plot.title = element_text(size = rel(2.5), color = "navyblue"),
        plot.subtitle = element_text(size = rel(2.2)),
        plot.caption = element_text(size = rel(1.2), colour = "grey20"),
        axis.text.x = element_text(size = rel(1.7)),
        axis.text.y = element_text(size = rel(1.7)),
        legend.title = element_text(size=rel(1.7)),
        legend.text = element_text(size = rel(1.5)),
        panel.grid = element_blank()
  ) +
  labs(title = "A Big Frog in a Small Pond?",
       subtitle = "Female frogs unlike males prefer ponds & reservoirs",
       caption = "TidyTuesday W-31 2022 | Data from USGS | by @TimirZolkin",
       color = "Location",
       y = "Number of frogs"
       )+
       ylim(0, 9)


frog_pic
# Out:
# `summarise()` has grouped output by 'SurveyDate', 'HabType'. You can override
# using the `.groups` argument.
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggsave("frog_pic.png", frog_pic, height = 5, width = 7, dpi = 125)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
